# %% [markdown]
# # 라벨 -데이터 프레임

# %%
import json
import pandas as pd
import os, os.path
import numpy as np 
import pandas as pd 
import os
import torch
import torchvision
import torch.nn as nn 
import torchvision.datasets as datasets
import torchvision.transforms as transforms 
import torch.nn.functional as F 
from torch.utils.data import DataLoader, Dataset 
from torchvision.datasets import ImageFolder
import torch.optim as optim 
from PIL import Image
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

train_path="D:/Train"
val_path="./폴더분리/Validation"
test_path="./폴더분리/Test"

# %%
"""
#train
image,h,w,Type,disease,crop,xtl,ytl,xbr, ybr=[],[],[],[],[],[],[],[],[],[]
file_list = os.listdir(train_path+'/라벨')

for file_name in file_list:
    json_file_path=train_path+'/라벨/'+file_name
    with open(json_file_path,'r') as j:
        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
    image.append(contents['description']['image'])
    Type.append(contents['description']['type'])
    crop.append(contents['annotations']['crop'])
    disease.append(contents['annotations']['disease'])
    h.append(contents['description']['height'])
    w.append(contents['description']['width'])
    xtl.append(contents['annotations']['points'][0]['xtl'])
    ytl.append(contents['annotations']['points'][0]['ytl'])
    xbr.append(contents['annotations']['points'][0]['xbr'])
    ybr.append(contents['annotations']['points'][0]['ybr'])
"""
# Out:
# "\n#train\nimage,h,w,Type,disease,crop,xtl,ytl,xbr, ybr=[],[],[],[],[],[],[],[],[],[]\nfile_list = os.listdir(train_path+'/라벨')\n\nfor file_name in file_list:\n    json_file_path=train_path+'/라벨/'+file_name\n    with open(json_file_path,'r') as j:\n        contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  \n    image.append(contents['description']['image'])\n    Type.append(contents['description']['type'])\n    crop.append(contents['annotations']['crop'])\n    disease.append(contents['annotations']['disease'])\n    h.append(contents['description']['height'])\n    w.append(contents['description']['width'])\n    xtl.append(contents['annotations']['points'][0]['xtl'])\n    ytl.append(contents['annotations']['points'][0]['ytl'])\n    xbr.append(contents['annotations']['points'][0]['xbr'])\n    ybr.append(contents['annotations']['points'][0]['ybr'])\n"

# %%
"""
train_graph=pd.DataFrame({
    "type":Type,
    "crop":crop,
    "disease":disease,
    "height":h,
    "width":w,
    "xtl":xtl,
    "ytl":ytl,
    "xbr":xbr,
    "ybr":ybr,    
    "name":image
})

train_graph
"""
# Out:
# '\ntrain_graph=pd.DataFrame({\n    "type":Type,\n    "crop":crop,\n    "disease":disease,\n    "height":h,\n    "width":w,\n    "xtl":xtl,\n    "ytl":ytl,\n    "xbr":xbr,\n    "ybr":ybr,    \n    "name":image\n})\n\ntrain_graph\n'

# %%
"""
#test
image,h,w,Type,disease,crop,xtl,ytl,xbr, ybr=[],[],[],[],[],[],[],[],[],[]
file_list = os.listdir(test_path+"/라벨")

for file_name in file_list:
    json_file_path=test_path+'/라벨/'+file_name
    with open(json_file_path,'r') as j:
        test_contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  
    image.append(test_contents['description']['image'])
    Type.append(test_contents['description']['type'])
    crop.append(test_contents['annotations']['crop'])
    disease.append(test_contents['annotations']['disease'])
    h.append(test_contents['description']['height'])
    w.append(test_contents['description']['width'])
    xtl.append(test_contents['annotations']['points'][0]['xtl'])
    ytl.append(test_contents['annotations']['points'][0]['ytl'])
    xbr.append(test_contents['annotations']['points'][0]['xbr'])
    ybr.append(test_contents['annotations']['points'][0]['ybr'])
    """
# Out:
# '\n#test\nimage,h,w,Type,disease,crop,xtl,ytl,xbr, ybr=[],[],[],[],[],[],[],[],[],[]\nfile_list = os.listdir(test_path+"/라벨")\n\nfor file_name in file_list:\n    json_file_path=test_path+\'/라벨/\'+file_name\n    with open(json_file_path,\'r\') as j:\n        test_contents=json.loads(j.read())  # open : r - 읽기모드, w-쓰기모드, a-추가모드  \n    image.append(test_contents[\'description\'][\'image\'])\n    Type.append(test_contents[\'description\'][\'type\'])\n    crop.append(test_contents[\'annotations\'][\'crop\'])\n    disease.append(test_contents[\'annotations\'][\'disease\'])\n    h.append(test_contents[\'description\'][\'height\'])\n    w.append(test_contents[\'description\'][\'width\'])\n    xtl.append(test_contents[\'annotations\'][\'points\'][0][\'xtl\'])\n    ytl.append(test_contents[\'annotations\'][\'points\'][0][\'ytl\'])\n    xbr.append(test_contents[\'annotations\'][\'points\'][0][\'xbr\'])\n    ybr.append(test_contents[\'annotations\'][\'points\'][0][\'ybr\'])\n    '

# %%
"""
test_graph=pd.DataFrame({
    "type":Type,
    "crop":crop,
    "disease":disease,
    "height":h,
    "width":w,
    "xtl":xtl,
    "ytl":ytl,
    "xbr":xbr,
    "ybr":ybr,    
    "name":image
})

test_graph
"""
# Out:
# '\ntest_graph=pd.DataFrame({\n    "type":Type,\n    "crop":crop,\n    "disease":disease,\n    "height":h,\n    "width":w,\n    "xtl":xtl,\n    "ytl":ytl,\n    "xbr":xbr,\n    "ybr":ybr,    \n    "name":image\n})\n\ntest_graph\n'

# %% [markdown]
# # 데이터 전처리(필요없음)

# %%
"""
from PIL import Image


for i in range(len(train_graph)):
    if train_graph['disease'][i]==0:
        path=train_path+'/0정상/'
    elif train_graph['disease'][i]==16:
        path=train_path+'/16흰가루병/'
    else:
        path=train_path+'/17노균병/'
        
    img=Image.open(path+train_graph['name'][i])

    img_cropped=img.crop((train_graph['xtl'][i],train_graph['ytl'][i],train_graph['xbr'][i],train_graph['ybr'][i]))
    a=str(i)
    img_cropped.save(path+'/'+a+'.jpg')
"""
# Out:
# "\nfrom PIL import Image\n\n\nfor i in range(len(train_graph)):\n    if train_graph['disease'][i]==0:\n        path=train_path+'/0정상/'\n    elif train_graph['disease'][i]==16:\n        path=train_path+'/16흰가루병/'\n    else:\n        path=train_path+'/17노균병/'\n        \n    img=Image.open(path+train_graph['name'][i])\n\n    img_cropped=img.crop((train_graph['xtl'][i],train_graph['ytl'][i],train_graph['xbr'][i],train_graph['ybr'][i]))\n    a=str(i)\n    img_cropped.save(path+'/'+a+'.jpg')\n"

# %%
"""
for i in range(len(test_graph)):
    if test_graph['disease'][i]==0:
        path=test_path+'/CNN/0정상/'
    elif test_graph['disease'][i]==16:
        path=test_path+'/CNN/16흰가루병/'
    else:
        path=test_path+'/CNN/17노균병/'
        
    img=Image.open(path+test_graph['name'][i])

    img_cropped=img.crop((test_graph['xtl'][i],test_graph['ytl'][i],test_graph['xbr'][i],test_graph['ybr'][i]))
    a=str(i)
    img_cropped.save(path+'/'+a+'.jpg')
    """
# Out:
# "\nfor i in range(len(test_graph)):\n    if test_graph['disease'][i]==0:\n        path=test_path+'/CNN/0정상/'\n    elif test_graph['disease'][i]==16:\n        path=test_path+'/CNN/16흰가루병/'\n    else:\n        path=test_path+'/CNN/17노균병/'\n        \n    img=Image.open(path+test_graph['name'][i])\n\n    img_cropped=img.crop((test_graph['xtl'][i],test_graph['ytl'][i],test_graph['xbr'][i],test_graph['ybr'][i]))\n    a=str(i)\n    img_cropped.save(path+'/'+a+'.jpg')\n    "

# %%
"""
c=[]
d=[]
file_list = os.listdir(train_path+'/1질병')
for i in range(len(train_graph)):
    if train_graph['name'][i] in file_list:
        if train_graph['disease'][i]==16:
            c.append(train_graph['name'][i] )
        elif train_graph['disease'][i]==17:
            d.append(train_graph['name'][i] )
            
#돌리지 말기
import shutil
import os

file_source = train_path+'/1질병/'
file_destination = train_path+'/16흰가루병' 
for g in c:
    shutil.move(file_source + g, file_destination)
    
file_source = train_path+'/1질병/'
file_destination = train_path+'/17노균병'    
for g in d:
    shutil.move(file_source + g, file_destination)
    """
# Out:
# "\nc=[]\nd=[]\nfile_list = os.listdir(train_path+'/1질병')\nfor i in range(len(train_graph)):\n    if train_graph['name'][i] in file_list:\n        if train_graph['disease'][i]==16:\n            c.append(train_graph['name'][i] )\n        elif train_graph['disease'][i]==17:\n            d.append(train_graph['name'][i] )\n            \n#돌리지 말기\nimport shutil\nimport os\n\nfile_source = train_path+'/1질병/'\nfile_destination = train_path+'/16흰가루병' \nfor g in c:\n    shutil.move(file_source + g, file_destination)\n    \nfile_source = train_path+'/1질병/'\nfile_destination = train_path+'/17노균병'    \nfor g in d:\n    shutil.move(file_source + g, file_destination)\n    "

# %%
"""
c=[]
d=[]
file_list = os.listdir(test_path+'/1질병')
for i in range(len(test_graph)):
    if test_graph['name'][i] in file_list:
        if test_graph['disease'][i]==16:
            c.append(test_graph['name'][i] )
        elif test_graph['disease'][i]==17:
            d.append(test_graph['name'][i] )
            
#돌리지 말기
import shutil
import os

file_source = test_path+'/1질병/'
file_destination = test_path+'/16흰가루병' 
for g in c:
    shutil.move(file_source + g, file_destination)
    
file_source = test_path+'/1질병/'
file_destination = test_path+'/17노균병'    
for g in d:
    shutil.move(file_source + g, file_destination)
"""
# Out:
# "\nc=[]\nd=[]\nfile_list = os.listdir(test_path+'/1질병')\nfor i in range(len(test_graph)):\n    if test_graph['name'][i] in file_list:\n        if test_graph['disease'][i]==16:\n            c.append(test_graph['name'][i] )\n        elif test_graph['disease'][i]==17:\n            d.append(test_graph['name'][i] )\n            \n#돌리지 말기\nimport shutil\nimport os\n\nfile_source = test_path+'/1질병/'\nfile_destination = test_path+'/16흰가루병' \nfor g in c:\n    shutil.move(file_source + g, file_destination)\n    \nfile_source = test_path+'/1질병/'\nfile_destination = test_path+'/17노균병'    \nfor g in d:\n    shutil.move(file_source + g, file_destination)\n"

# %% [markdown]
# # CNN 구현

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers
import os
import matplotlib.pyplot as plt
from tensorflow.keras.layers.experimental import preprocessing
# Out:
# Using TensorFlow backend.

# %%
#path 바꿔가면서 돌림 (원천데이터만// 증강데이터 포함)

train_path='D:/Train'
val_path='./폴더분리/Validation'
test_path='./폴더분리/Test'

# %%
batch_size = 16
image_size=(120,120)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    seed=1337,
    shuffle=True,
    image_size=image_size,
    batch_size=batch_size
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_path,
    seed=1337,
    shuffle=True,
    image_size=image_size,
    batch_size=batch_size
)
# Out:
# Found 1464 files belonging to 3 classes.
# Found 135 files belonging to 3 classes.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(int(labels[i]))
        plt.axis("off")

# %% [markdown]
# train_ds = train_ds.prefetch(buffer_size=16)
# val_ds = val_ds.prefetch(buffer_size=16)

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# # CNN MODEL (ResNet)

# %%
def make_model(input_shape, num_classes):
    # Image augmentation 
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = preprocessing.Rescaling(1.0 / 255)(x)

    x = layers.Conv2D(32, 3, kernel_initializer="HeNormal", bias_initializer='zeros', strides=2, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.Conv2D(64, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    for size in [128, 256, 512,728]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(size, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(size, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    x = layers.SeparableConv2D(1024, 3, padding="same")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    x = layers.GlobalAveragePooling2D()(x)
    if num_classes == 2:
        activation = "sigmoid"
        units = 1
    else:
        activation = "softmax"
        units = num_classes

    x = layers.Dropout(0.25)(x)
    outputs = layers.Dense(units, activation=activation)(x)
    return keras.Model(inputs, outputs)


model = make_model(input_shape=image_size + (3,), num_classes=3)

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            [(None, 120, 120, 3) 0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 120, 120, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# rescaling_1 (Rescaling)         (None, 120, 120, 3)  0           sequential_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 60, 60, 32)   896         rescaling_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 60, 60, 32)   128         conv2d_6[0][0]
# ...

# %%
from tensorflow.keras.utils import plot_model
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %matplotlib inline


plot_model(model, show_shapes=True, to_file='pre_model.png')

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 14990037042847873766
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1738407936
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 12738396988186325724
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3050 Ti Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
# xla_global_id: 416903419
# ]

# %%
epochs = 100


callbacks = [
    keras.callbacks.ModelCheckpoint("save_at_{epoch}.h5"),
]
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
history=model.fit(
    train_ds, epochs=epochs, callbacks=callbacks, validation_data=val_ds,
)
# Out:
# Epoch 1/100
# 92/92 [==============================] - 8s 68ms/step - loss: 0.7658 - accuracy: 0.6851 - val_loss: 1.2441 - val_accuracy: 0.3333
# Epoch 2/100
# 92/92 [==============================] - 6s 67ms/step - loss: 0.4483 - accuracy: 0.8279 - val_loss: 1.6181 - val_accuracy: 0.3333
# Epoch 3/100
# 92/92 [==============================] - 6s 68ms/step - loss: 0.3198 - accuracy: 0.8770 - val_loss: 1.8285 - val_accuracy: 0.3333
# Epoch 4/100
# 92/92 [==============================] - 6s 67ms/step - loss: 0.2472 - accuracy: 0.9085 - val_loss: 1.1094 - val_accuracy: 0.4889
# Epoch 5/100
# 92/92 [==============================] - 6s 68ms/step - loss: 0.1876 - accuracy: 0.9276 - val_loss: 0.6954 - val_accuracy: 0.7259
# Epoch 6/100
# 92/92 [==============================] - 7s 69ms/step - loss: 0.1326 - accuracy: 0.9426 - val_loss: 0.9403 - val_accuracy: 0.6593
# Epoch 7/100
# ...

# %%
def show_train_history(train_history, train_metrics, validation_metrics):
    plt.plot(train_history.history[train_metrics])
    plt.plot(train_history.history[validation_metrics])
    plt.title('Train History')
    plt.ylabel(train_metrics)
    plt.xlabel('Epoch')
    plt.legend(['train', 'validation'], loc='upper left')

    
def plot(history):
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 2, 1)
    show_train_history(history, 'accuracy', 'val_accuracy')
    plt.subplot(1, 2, 2)
    show_train_history(history, 'loss', 'val_loss')
    plt.show()

plot(history)

# %%
#모델 저장 및 불러오기
#from keras.models import load_model
#model.save('./model_CNN_GAN100.h5')

#from keras.models import load_model
#model = load_model('./model_name.h5')

# %% [markdown]
# # Test

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    seed=1337,
    image_size=image_size,
    batch_size=135)

test_x,test_y=[],[]
for img,label in test_ds:
    test_x.append(img)
    for i in range(135):
        test_y.append(float(label[i]))
# Out:
# Found 135 files belonging to 3 classes.

# %%
import numpy as np
def my_func(arg):
  arg = tf.convert_to_tensor(arg, dtype=tf.float32)
  return arg

test_y= my_func(test_y)

# %%
loss_and_metrics = model.evaluate(test_x, test_y, batch_size=16)
print('')
print('loss_and_metrics : ' + str(loss_and_metrics))
# Out:
# 9/9 [==============================] - 0s 14ms/step - loss: 0.5132 - accuracy: 0.8963
#
# loss_and_metrics : [0.5132037997245789, 0.8962963223457336]

# %% [markdown]
# # Confusion Matrix

# %%
predict_x = model.predict(test_x)
classes_x=np.argmax(predict_x,axis=1)

# %%
predict_x[0]
# Out:
# array([6.7736892e-06, 3.1117488e-05, 9.9996209e-01], dtype=float32)

# %%
np.array(test_y,dtype=int)
# Out:
# array([2, 2, 2, 2, 2, 0, 2, 0, 2, 0, 1, 0, 1, 1, 0, 1, 0, 1, 2, 1, 0, 0,
#        2, 1, 1, 2, 1, 1, 0, 0, 2, 2, 0, 2, 0, 1, 0, 2, 2, 0, 2, 1, 1, 2,
#        2, 0, 2, 0, 2, 1, 1, 1, 1, 0, 1, 2, 2, 0, 1, 0, 1, 1, 2, 2, 0, 1,
#        2, 0, 0, 1, 1, 1, 1, 0, 2, 1, 0, 0, 1, 1, 2, 2, 0, 0, 0, 0, 0, 2,
#        0, 0, 1, 2, 2, 1, 2, 1, 1, 2, 0, 0, 2, 1, 1, 1, 1, 1, 2, 0, 2, 0,
#        1, 2, 0, 0, 2, 2, 0, 2, 0, 0, 2, 1, 0, 1, 1, 0, 1, 2, 1, 2, 2, 1,
#        0, 0, 2])

# %%
y_test=[]
for i in test_y:
    if i==0:
        y_test.append([1,0,0])
    elif i==1:
        y_test.append([0,1,0])
    else:
        y_test.append([0,0,1])
        
y_score=[]

for i in predict_x:
    y_score.append(i.tolist())

# %%
# Look at confusion matrix
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting 'normalize=True'.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks=np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, cm[i, j], horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    
    
# compute the confusion matrix
confusion_mtx = confusion_matrix(np.array(test_y,dtype=int), classes_x)
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(3))
